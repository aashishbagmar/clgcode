# %%
## Deep Learning Lab 3- Design RNN or its variant including LSTM or GRU

import numpy as np
import tensorflow as tf

from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 2. Parameters
max_features = 10000
maxlen = 100
batch_size = 32
epochs = 5

# 3. Load Dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# 4. Preprocessing
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# 5. Build Model (Improved)
model = Sequential()

# Embedding Layer
model.add(Embedding(input_dim=max_features, output_dim=128, input_length=maxlen))

# LSTM Layer
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))

# Extra Dropout (added)
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

# 6. Compile Model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# 7. Train Model
history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test)
)

# 8. Evaluate Model
score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print("Test Loss:", score)
print("Test Accuracy:", acc)

# Predict sentiment for sample review

sample_review = x_test[4].reshape(1, -1)

prediction = model.predict(sample_review)

print("Prediction Value:", prediction)

if prediction[0][0] > 0.5:  
    print("Positive Review")
else:
    print("Negative Review")
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - accuracy: 0.7827 - loss: 0.4645 - val_accuracy: 0.8446 - val_loss: 0.3622
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8643 - loss: 0.3267 - val_accuracy: 0.8293 - val_loss: 0.3805
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9010 - loss: 0.2528 - val_accuracy: 0.8459 - val_loss: 0.3789
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9241 - loss: 0.1980 - val_accuracy: 0.8399 - val_loss: 0.4012
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9398 - loss: 0.1620 - val_accuracy: 0.8324 - val_loss: 0.4502
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8324 - loss: 0.4502
# Test Loss: 0.4501921236515045
# Test Accuracy: 0.8324400186538696
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Prediction Value: [[0.99992526]]
# Positive Review

# %%
if prediction[1][0] > 0.5:
    print("Positive Review")
else:
    print("Negative Review")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 if prediction[1][0] > 0.5:
#       2     print("Positive Review")
#       3 else:
#       4     print("Negative Review")
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
